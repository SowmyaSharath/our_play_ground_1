# %%
import pandas as pd


# In[83]:
df = pd.read_csv('Data_Train.csv')
df.head(10)
print(df.shape)
# Out:
# (78458, 11)

# %%
#Replace K, M, B
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    if ',' in x:
        return float(x.replace(',', '')) 
    return float(x)

df.Likes = df.Likes.apply(value_to_float)
df.Popularity = df.Popularity.apply(value_to_float)
df.to_csv('Data_Train_Transformed_1.csv')
df = df[df['Views'] > df["Likes"]]
print(df.shape)
print(df.head())
# Out:
# (77170, 11)
#    Unique_ID              Name     Genre Country  \
# 0     413890         Hardstyle  danceedm      AU
# 1     249453        Dj Aladdin  danceedm      AU
# 2     681116  Maxximize On Air  danceedm      AU
# 3     387253       GR6 EXPLODE    rbsoul      AU
# 4    1428029          Tritonal  danceedm      AU
#
#                                            Song_Name  \
# 0  N-Vitral presents BOMBSQUAD - Poison Spitter (...
# 1          Dj Aladdin - Old School Hip Hop Quick Mix
# 2  Maxximize On Air - Mixed by Blasterjaxx - Epis...
# 3                MC Yago - Tenho Compromisso (DJ R7)
# 4                         Escape (feat. Steph Jones)
#
#                     Timestamp   Views  Comments   Likes  Popularity  Followers
# 0  2018-03-30 15:24:45.000000   14017         4   499.0        97.0     119563
# 1  2016-06-20 05:58:52.000000    1918        17    49.0        17.0       2141
# 2  2015-05-08 17:45:59.000000    9668        11   312.0        91.0      22248
# 3  2017-06-08 23:50:03.000000  113036         2  2400.0        76.0     393655
# 4  2016-09-17 20:50:19.000000  110024        81  3031.0       699.0     201030

# %%
df.isnull().sum()
# Out:
# Unique_ID     0
# Name          0
# Genre         0
# Country       0
# Song_Name     1
# Timestamp     0
# Views         0
# Comments      0
# Likes         0
# Popularity    0
# Followers     0
# dtype: int64

# %%
# Distribution of features by Genre
df_mean = df.groupby('Genre').mean()
df_mean
# Out:
#                          Unique_ID         Views    Comments         Likes  \
# Genre
# all-music             7.996840e+05  2.454978e+06  294.812007  36307.722834
# alternativerock       7.715628e+05  8.545917e+05  190.173077  11453.076923
# ambient               1.101245e+06  4.262042e+05   94.012626   6845.500000
# classical             9.667382e+05  3.931904e+05   91.676662   7339.490222
# country               5.000266e+05  2.945058e+05  124.800595   5161.773810
# danceedm              7.100286e+05  2.673978e+05  115.092053   4892.249845
# deephouse             1.160870e+06  6.264949e+04   66.227404   1641.210070
# disco                 3.550677e+05  5.235317e+05  122.627376   8923.003802
# drumbass              5.862023e+05  3.712738e+04   67.277198   1334.828614
# dubstep               6.606288e+05  2.422849e+05  168.148216   5888.222324
# electronic            7.150612e+05  1.820002e+05  103.775014   3846.111206
# folksingersongwriter  1.023424e+06  4.753422e+05   31.128205   7962.538462
# hiphoprap             6.424885e+05  2.145161e+06  326.570000  40382.960000
# indie                 1.343443e+05  1.657772e+06  144.181818  34810.000000
# latin                 5.118163e+05  2.366119e+05    8.061211   2887.111233
# metal                 1.211897e+06  1.326302e+05   15.482283   1485.868110
# pop                   9.758440e+05  3.630477e+05   75.351351   6401.788288
# rbsoul                4.540655e+05  6.098673e+05   50.984280  10145.821898
# reggaeton             4.255708e+05  1.149190e+06   27.763636  14180.727273
# rock                  8.693438e+05  1.364378e+05   24.442986   1843.896782
# trap                  9.527589e+05  2.798408e+05   95.293633   5195.660175
#
#                        Popularity     Followers
# Genre
# all-music             2487.344703  9.580586e+05
# alternativerock        931.769231  1.935528e+05
# ambient               1021.780303  2.397200e+05
# classical             1141.687093  6.705102e+05
# country                712.821429  1.100058e+06
# danceedm               834.761185  6.596372e+05
# deephouse              307.310359  9.857645e+04
# disco                 1857.562738  5.688260e+05
# drumbass               224.774963  5.063995e+04
# dubstep               1105.865508  1.407731e+05
# electronic             692.164494  3.565977e+05
# folksingersongwriter   455.307692  5.625203e+04
# hiphoprap             5034.680000  2.282266e+05
# indie                 4087.909091  9.573300e+04
# latin                   91.901931  8.210619e+03
# metal                   94.692913  5.068780e+05
# pop                    658.257320  4.522796e+05
# rbsoul                 898.717773  2.086251e+05
# reggaeton              393.418182  7.825273e+03
# rock                   121.599743  4.068367e+05
# trap                   887.740075  1.727215e+05

# %%
#Correlation matrix
print(df.head())
df.drop(['Unique_ID','Country','Timestamp','Comments','Song_Name','Followers'],inplace = True, axis = 1)
df.head()
# Out:
#    Unique_ID              Name     Genre Country  \
# 0     413890         Hardstyle  danceedm      AU
# 1     249453        Dj Aladdin  danceedm      AU
# 2     681116  Maxximize On Air  danceedm      AU
# 3     387253       GR6 EXPLODE    rbsoul      AU
# 4    1428029          Tritonal  danceedm      AU
#
#                                            Song_Name  \
# 0  N-Vitral presents BOMBSQUAD - Poison Spitter (...
# 1          Dj Aladdin - Old School Hip Hop Quick Mix
# 2  Maxximize On Air - Mixed by Blasterjaxx - Epis...
# 3                MC Yago - Tenho Compromisso (DJ R7)
# 4                         Escape (feat. Steph Jones)
#
#                     Timestamp   Views  Comments   Likes  Popularity  Followers
# 0  2018-03-30 15:24:45.000000   14017         4   499.0        97.0     119563
# 1  2016-06-20 05:58:52.000000    1918        17    49.0        17.0       2141
# 2  2015-05-08 17:45:59.000000    9668        11   312.0        91.0      22248
# 3  2017-06-08 23:50:03.000000  113036         2  2400.0        76.0     393655
# 4  2016-09-17 20:50:19.000000  110024        81  3031.0       699.0     201030
#                Name     Genre   Views   Likes  Popularity
# 0         Hardstyle  danceedm   14017   499.0        97.0
# 1        Dj Aladdin  danceedm    1918    49.0        17.0
# 2  Maxximize On Air  danceedm    9668   312.0        91.0
# 3       GR6 EXPLODE    rbsoul  113036  2400.0        76.0
# 4          Tritonal  danceedm  110024  3031.0       699.0

# %%
#Correlation
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (6,4))
cmap = df.corr()
sns.heatmap(cmap, annot = True)

# %%
# Remove Outliers of Popularity
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df['Popularity']))
df = df[(z < 3)]
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(16,8))
# #ax.scatter(df['Unique_ID'], df['Popularity'])
# ax.set_xlabel('Unique Id')
# ax.set_ylabel('Popularity')

# Remove Outliers of Views
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df['Views']))
df = df[(z < 3)]
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(16,8))
# #ax.scatter(df['Unique_ID'], df['Views'])
# ax.set_xlabel('Unique Id')
# ax.set_ylabel('Views')

# Remove Outliers of Likes
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df['Likes']))
df = df[(z < 3)]
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(16,8))
# #ax.scatter(df['Unique_ID'], df['Likes'])
# ax.set_xlabel('Unique Id')
# ax.set_ylabel('Likes')

print(df.shape)
# Out:
# (73394, 5)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
# Extracting Genre, Likes, Popularity to X & Views to Y
#Removing outliers
labelencoder = LabelEncoder()
df['Genre'] = labelencoder.fit_transform(df['Genre'])
df['Name'] = labelencoder.fit_transform(df['Name'])
df.head()
# Out:
#    Name  Genre   Views   Likes  Popularity
# 0   394      5   14017   499.0        97.0
# 1   263      5    1918    49.0        17.0
# 2   624      5    9668   312.0        91.0
# 3   357     17  113036  2400.0        76.0
# 4   961      5  110024  3031.0       699.0

# %%
#Standard scaling
from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import StandardScaler
# sc_x = StandardScaler()
# ct = ColumnTransformer([
#         ('somename', StandardScaler(), ['Name', 'Genre', 'Likes', 'Popularity'])
#     ], remainder='passthrough')
from sklearn.preprocessing import MinMaxScaler
sc_x = MinMaxScaler()
ct = ColumnTransformer([
        ('somename', MinMaxScaler(), ['Genre','Name','Likes', 'Popularity'])
    ], remainder='passthrough')
df_scaled = ct.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled)
print(df_scaled.head())
# Out:
#       0         1         2         3         4
# 0  0.25  0.329707  0.015994  0.006510   14017.0
# 1  0.25  0.220084  0.001571  0.001141    1918.0
# 2  0.25  0.522176  0.010000  0.006107    9668.0
# 3  0.85  0.298745  0.076923  0.005101  113036.0
# 4  0.25  0.804184  0.097147  0.046913  110024.0
# D:\Applns\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
# import sklearn as sklearn
# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# # ngram level tf-idf 
# tfidf_vect_ngram = TfidfVectorizer(analyzer='word',  ngram_range=(2,3), max_features=100)
# fitted_vec = tfidf_vect_ngram.fit_transform(df_scaled[4].values.astype('U'))

# df_song_name = pd.DataFrame(fitted_vec.toarray(), columns=tfidf_vect_ngram.get_feature_names())

# %%
# df_scaled = df_scaled.join(df_song_name)
# df_scaled.head()
# df_scaled.drop([4],inplace = True, axis = 1)
# df_scaled.head()

# %%
#Removing outliers using IQR
Q1 = df_scaled.quantile(0.25,axis=1,numeric_only=True)
Q3 = df_scaled.quantile(0.75,axis=1,numeric_only=True)
IQR = Q3 - Q1
#df = df[~((df["Likes"] < (Q1 - 1.5 * IQR)) |(df["Likes"] > (Q3 + 1.5 * IQR)))]
df_scaled = df_scaled[~((df_scaled < (Q1 - 1.5 * IQR)) |(df_scaled > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_scaled.shape)
df_scaled.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-d18a429ad678> in <module>()
#       4 IQR = Q3 - Q1
#       5 #df = df[~((df["Likes"] < (Q1 - 1.5 * IQR)) |(df["Likes"] > (Q3 + 1.5 * IQR)))]
# ----> 6 df_scaled = df_scaled[~((df_scaled < (Q1 - 1.5 * IQR)) |(df_scaled > (Q3 + 1.5 * IQR))).any(axis=1)]
#       7 print(df_scaled.shape)
#       8 df_scaled.head()
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1618             return _combine_series_frame(self, other, func,
#    1619                                          fill_value=None, axis=None,
# -> 1620                                          level=None, try_cast=False)
#    1621         else:
#    1622
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\ops.py in _combine_series_frame(self, other, func, fill_value, axis, level, try_cast)
#    1437         # default axis is columns
#    1438         return self._combine_match_columns(other, func, level=level,
# -> 1439                                            try_cast=try_cast)
#    1440
#    1441
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_match_columns(self, other, func, level, try_cast)
#    4767     def _combine_match_columns(self, other, func, level=None, try_cast=True):
#    4768         left, right = self.align(other, join='outer', axis=1, level=level,
# -> 4769                                  copy=False)
#    4770
#    4771         new_data = left._data.eval(func=func, other=right,
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\frame.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3548                                             method=method, limit=limit,
#    3549                                             fill_axis=fill_axis,
# -> 3550                                             broadcast_axis=broadcast_axis)
#    3551
#    3552     @Appender(_shared_docs['reindex'] % _shared_doc_kwargs)
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    7370                                       copy=copy, fill_value=fill_value,
#    7371                                       method=method, limit=limit,
# -> 7372                                       fill_axis=fill_axis)
#    7373         else:  # pragma: no cover
#    7374             raise TypeError('unsupported type: %s' % type(other))
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    7467
#    7468                 if lidx is not None:
# -> 7469                     fdata = fdata.reindex_indexer(join_index, lidx, axis=0)
#    7470             else:
#    7471                 raise ValueError('Must specify axis=0 or 1')
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    4419         if axis == 0:
#    4420             new_blocks = self._slice_take_blocks_ax0(indexer,
# -> 4421                                                      fill_tuple=(fill_value,))
#    4422         else:
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\internals.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    4482
#    4483                 blocks.append(self._make_na_block(placement=mgr_locs,
# -> 4484                                                   fill_value=fill_value))
#    4485             else:
#    4486                 blk = self.blocks[blkno]
#
# D:\Applns\Anaconda3\lib\site-packages\pandas\core\internals.py in _make_na_block(self, placement, fill_value)
#    4512
#    4513         dtype, fill_value = infer_dtype_from_scalar(fill_value)
# -> 4514         block_values = np.empty(block_shape, dtype=dtype)
#    4515         block_values.fill(fill_value)
#    4516         return make_block(block_values, placement=placement)
#
# MemoryError:

# %%
y = df_scaled[4]
df_scaled.to_csv('X_And_Y.csv')
df_scaled.drop([4],inplace = True, axis = 1)

# %%
df_scaled.describe()
df_scaled.plot.hist()

# %%
y.plot.hist()

# %%
from sklearn.model_selection import train_test_split
print(df_scaled)
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df_scaled, y, test_size=.2, random_state=205)

# %%
#XGB Boost regression
import xgboost as xgb
xlf = xgb.XGBRegressor()
xlf.fit(X_train, y_train, eval_metric='rmse', verbose = True, eval_set = [(X_test, y_test)])
# calculate the auc score
y_pred = xlf.predict(X_test)
#RMSE - Test
print("XGBoost - Linear regression: ", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))

# %%
#Implementing Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn import metrics

linear = LinearRegression()
linear.fit(X_train, y_train)
y_pred = linear.predict(X_test)
print("RMSE - Linear regression: ", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
